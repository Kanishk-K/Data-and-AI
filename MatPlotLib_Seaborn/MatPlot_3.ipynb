# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use("fivethirtyeight")
plt.title("Pie Chart Project")
plt.tight_layout()

slices = [60,40]
plt.pie(slices)

plt.show()
